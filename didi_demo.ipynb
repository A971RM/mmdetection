# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %%
# 指定模型及其对应的训练模型
config_file = './configs/faster_rcnn/faster_rcnn_r50_fpn_1x_didi.py'
checkpoint_file = './work_dirs/faster_rcnn_r50_fpn_1x_didi/epoch_12.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: ./work_dirs/faster_rcnn_r50_fpn_1x_didi/epoch_12.pth

# %%
# test a single image
img = r'E:\\job\\code\\github\\A971RM\\datasets\\didi\\dataset_release\\test\\11012.jpg'
result = inference_detector(model, img)

# %%
# show the results
show_result_pyplot(model, img, result)
